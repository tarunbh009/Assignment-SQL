# %% [markdown]
# # Q-13. Write an SQL query to show only odd rows from a table.

# %%
import mysql.connector as connection
mydb=connection.connect(host='localhost',user='root',passwd='mysql',database='ineuron',use_pure=True)
cur=mydb.cursor()
cur.execute('select * from worker where MOD(ID,2)<>0')
print(cur.fetchall())
# Out:
# [(1, 'Anand', 'Issac', 'Marketing', 40000, 'ananac@ineauron.com', datetime.date(2015, 4, 22), 1), (1, 'Anand', 'Issac', 'Marketing', 40000, 'ananac@ineauron.com', datetime.date(2015, 4, 22), 3), (3, 'Amitabh', 'Thej', 'Marketing', 10000, 'Amitabhthj@ineauron.com', datetime.date(2006, 3, 17), 5), (5, 'Heena', 'Mangat', 'HR', 50000, 'heenamgat@ineauron.com', datetime.date(2016, 12, 10), 7), (7, 'Mohit ', 'Bahl', 'Finance', 50000, 'mohitbhl@gmail.com', datetime.date(2017, 2, 16), 9), (9, 'Satish', 'Bhat', 'HR', 25000, 'Sathishbht@ineauron.com', datetime.date(2017, 5, 13), 11), (11, 'Anil', 'Gobin', 'Finance', 30000, 'anilgoin@ineauron.com', datetime.date(2014, 2, 18), 13), (13, 'Kajol', 'Behl', 'Finance', 45000, 'kajolhl@ineauron.com', datetime.date(2015, 9, 30), 15)]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q-14. Write an SQL query to clone a new table from another table.

# %%
cur.execute('create table worker2 like worker')
cur.execute('insert into worker2 select * from worker')
cur.execute('select * from worker2')
print(cur.fetchall())
# Out:
# [(1, 'Anand', 'Issac', 'Marketing', 40000, 'ananac@ineauron.com', datetime.date(2015, 4, 22), 1), (2, 'Aayushi', 'Natarajan', 'Purchase', 35000, 'aayushan@gmail.com', datetime.date(2015, 5, 14), 2), (1, 'Anand', 'Issac', 'Marketing', 40000, 'ananac@ineauron.com', datetime.date(2015, 4, 22), 3), (2, 'Aayushi', 'Natarajan', 'Purchase', 35000, 'aayushan@gmail.com', datetime.date(2015, 5, 14), 4), (3, 'Amitabh', 'Thej', 'Marketing', 10000, 'Amitabhthj@ineauron.com', datetime.date(2006, 3, 17), 5), (4, 'Kajol', 'Behl', 'Finance', 45000, 'kajolhl@ineauron.com', datetime.date(2015, 9, 30), 6), (5, 'Heena', 'Mangat', 'HR', 50000, 'heenamgat@ineauron.com', datetime.date(2016, 12, 10), 7), (6, 'Vipul', 'Kapoor', 'Purchase', 30000, 'Vipulk@ineauron.com', datetime.date(2015, 7, 11), 8), (7, 'Mohit ', 'Bahl', 'Finance', 50000, 'mohitbhl@gmail.com', datetime.date(2017, 2, 16), 9), (8, 'Pranay ', 'Rastogi', 'Marketing', 45000, 'pranagi@ineauron.com', datetime.date(2014, 2, 12), 10), (9, 'Satish', '
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
